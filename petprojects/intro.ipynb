# %% [markdown]
# ### to serve this as slides, run this
# `jupyter nbconvert Documents\mlart\PPPres\ML_ART_project_presentation.ipynb --to slides --post serve`
#
# refer to this medium post for more info https://medium.com/@mjspeck/presenting-code-using-jupyter-notebook-slides-a8a3c3b59d67

# %% [markdown]
# # 🤖📚🎨 Machine Learning Art

# %% [markdown]
# # Что такое медиаискусство?
#
# ![alt text](planetarium_keanu.png)

# %% [markdown]
# # Где посмотреть?
# - planetarium.one
#
# - hyport.ru
#
# - Галерея Марс

# %% [markdown]
# # онлайн 😷
#
# www.generativegallery.com
#
# http://kzgallery.com/

# %% [markdown]
# # Инструменты медиахудожников
#
# ![](touchdesigner.jpg)

# %% [markdown]
# - Touchdesigner
#
# - Notch
#
# - OpenFrameworks
#
# - RunwayML

# %% [markdown]
# # При чем тут машинное обучение?

# %% [markdown]
# # Machine Learning Art: Open Call
#
# https://mlart.org/datafest

# %% [markdown]
# # Присоединяйтесь к проекту!
#
# Для участия, заполните анкету на сайте:
#
# ## [mlart.org](mlart.org/datafest)
#
# ### Канал в slack со всей информацией: #mlart
